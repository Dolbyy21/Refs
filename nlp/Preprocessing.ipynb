# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
mytext = """In the previous chapter, we saw examples of some common NLP 
applications that we might encounter in everyday life. If we were asked to 
build such an application, think about how we would approach doing so at our 
organization. We would normally walk through the requirements and break the 
problem down into several sub-problems, then try to develop a step-by-step 
procedure to solve them. Since language processing is involved, we would also
list all the forms of text processing needed at each step. This step-by-step 
processing of text is known as pipeline. It is the series of steps involved in
building any NLP model. These steps are common in every NLP project, so it 
makes sense to study them in this chapter. Understanding some common procedures
in any NLP pipeline will enable us to get started on any NLP problem encountered 
in the workplace. Laying out and developing a text-processing pipeline is seen 
as a starting point for any NLP application development process. In this
chapter, we will learn about the various steps involved and how they play  
important roles in solving the NLP problem and we’ll see a few guidelines
about when and how to use which step. In later chapters, we’ll discuss  
specific pipelines for various NLP tasks (e.g., Chapters 4–7)."""

# %%
mytext
# Out:
# 'In the previous chapter, we saw examples of some common NLP \napplications that we might encounter in everyday life. If we were asked to \nbuild such an application, think about how we would approach doing so at our \norganization. We would normally walk through the requirements and break the \nproblem down into several sub-problems, then try to develop a step-by-step \nprocedure to solve them. Since language processing is involved, we would also\nlist all the forms of text processing needed at each step. This step-by-step \nprocessing of text is known as pipeline. It is the series of steps involved in\nbuilding any NLP model. These steps are common in every NLP project, so it \nmakes sense to study them in this chapter. Understanding some common procedures\nin any NLP pipeline will enable us to get started on any NLP problem encountered \nin the workplace. Laying out and developing a text-processing pipeline is seen \nas a starting point for any NLP application development process.
# ...

# %%
nltk.download('punkt')
my_sentences = sent_tokenize(mytext)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dolby\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(len(my_sentences))
my_sentences
# Out:
# 11
# ['In the previous chapter, we saw examples of some common NLP \napplications that we might encounter in everyday life.',
#  'If we were asked to \nbuild such an application, think about how we would approach doing so at our \norganization.',
#  'We would normally walk through the requirements and break the \nproblem down into several sub-problems, then try to develop a step-by-step \nprocedure to solve them.',
#  'Since language processing is involved, we would also\nlist all the forms of text processing needed at each step.',
#  'This step-by-step \nprocessing of text is known as pipeline.',
#  'It is the series of steps involved in\nbuilding any NLP model.',
#  'These steps are common in every NLP project, so it \nmakes sense to study them in this chapter.',
#  'Understanding some common procedures\nin any NLP pipeline will enable us to get started on any NLP problem encountered \nin the workplace.',
# ...

# %%
i = 1
for sentence in my_sentences:
    
    print("THIS IS SENTENCE {} \n".format(i))
    print(sentence)
    print("\n")
    print("WORDS : \n")
    print(word_tokenize(sentence))
    print("\n\n\n")
    i+=1
# Out:
# THIS IS SENTENCE 1
#
# In the previous chapter, we saw examples of some common NLP
# applications that we might encounter in everyday life.
#
#
# WORDS :
#
# ['In', 'the', 'previous', 'chapter', ',', 'we', 'saw', 'examples', 'of', 'some', 'common', 'NLP', 'applications', 'that', 'we', 'might', 'encounter', 'in', 'everyday', 'life', '.']
#
#
#
#
# THIS IS SENTENCE 2
#
# If we were asked to
# build such an application, think about how we would approach doing so at our
# organization.
#
#
# WORDS :
#
# ['If', 'we', 'were', 'asked', 'to', 'build', 'such', 'an', 'application', ',', 'think', 'about', 'how', 'we', 'would', 'approach', 'doing', 'so', 'at', 'our', 'organization', '.']
#
#
#
#
# THIS IS SENTENCE 3
#
# We would normally walk through the requirements and break the
# problem down into several sub-problems, then try to develop a step-by-step
# procedure to solve them.
#
#
# WORDS :
#
# ...

# %% [markdown]
# # Frequent Steps
# ### categorization of news, sports, politics articles (classification)
# * stop words and are typically (though not always) removed from further analysis in such   problem scenarios.
# * although what a stop word is can vary depending on what we’re working on. For example, the word “news” is perhaps a stop word for this problem scenario, but it may not be a stop word for the offer letter for a job.
# * Similarly, in some cases, upper or lowercase may not make a difference for the problem. So, all text is lowercased (or uppercased, although lowercasing is more common).
# * Removing punctuation and/or numbers is also a common step for many NLP problems such as text classification, information retrieval, and social media analytics.

# %% [markdown]
# ##### The code example below shows how to remove stop words, digits, and punctuation and lowercase a given collection of texts

# %%
# need to download stopwords for the first time if it doesn't download automatically
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dolby\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
my_stop_words = set(stopwords.words("english")) # returns set of stopwords in english
from string import punctuation
print(type(punctuation))
print(punctuation,"\n\n")
texts = ["first 1 , dsfasdfkfm . efaw firstlast", "second , ' ' * {} 145 secondlast"]
print(f'Example texts are : \n   1. {texts[0]} \n   2. {texts[1]}\n')
for text in texts:
        
        # tokenize the text 
        tokens = word_tokenize(text)
        print(tokens)
        
        
        lower_without_stopwords = [token.lower() for token in tokens if token not in my_stop_words and 
                                  not token.isdigit() and token not in punctuation]
        print("ANS :", lower_without_stopwords,"\n")
# Out:
# <class 'str'>
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
#
# Example texts are :
#    1. first 1 , dsfasdfkfm . efaw firstlast
#    2. second , ' ' * {} 145 secondlast
#
# ['first', '1', ',', 'dsfasdfkfm', '.', 'efaw', 'firstlast']
# ANS : ['first', 'dsfasdfkfm', 'efaw', 'firstlast']
#
# ['second', ',', "'", "'", '*', '{', '}', '145', 'secondlast']
# ANS : ['second', 'secondlast']

# %% [markdown]
# * We are not doing any liguistic related on the above things, just removing the punctuation(which are common in any language) and removing stopwords freuency (since they are freuently used and not rmeoving them might lead to noise)

# %% [markdown]
# # Stemming
# * Stemming is removing suffixes to reduce the similar words to a base word form, (cars, car -> reduced to car) (bat, batting -> reduced to bat)
# * This is accomplished by applying a fixed set of rules (e.g., if the word ends in “-es,” remove “-es”)
#  * Although such rules may not always end up in a linguistically correct base form, stemming is commonly used in search engines to match user queries to relevant documents and in text classification to reduce the feature space to train machine learning models.

# %% [markdown]
# ###### Porter Stemmer using NLTK

# %% [markdown]
# * PorterStemmer Can be imported from nltk.stem.porter
#  * Syntax : porter_stemmer_obj.stem(word, to_lowercase=True)

# %%
from nltk.stem.porter import PorterStemmer

# %%
# Initializing porter stemmer object
stemmer = PorterStemmer()

# %%
words = ['cars', 'buses', 'removes', 'Movies', 'Moves', 'revolution', 'revoult', 'revolutionary']
[stemmer.stem(word) for word in words]
# Out:
# ['car', 'buse', 'remov', 'movi', 'move', 'revolut', 'revoult', 'revolutionari']

# %% [markdown]
# * This gives “car” as the stemmed version for “cars,” but “revolut” as the stemmed form of “revolution,” even though the latter is not linguistically correct. While this may not affect the performance of a search engine, derivation of correct linguistic form becomes useful in some other scenarios. This is accomplished by another process, closer to stemming, called lemmatization.

# %% [markdown]
# # Lemmatization
# * Lemmatization is the process of mapping all the different forms of a word to its base word or lemma (better -> good)
# * Lemmatization requires more linguistic knowledge, and modeling and developing efficient lemmatizers remains an open problem in NLP research even now.

# %% [markdown]
# * The following code snippet shows the usage of a lemmatizer based on WordNet from NLTK

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer

# %%
nltk.download('wordnet') # download if this doesn't downloaded automatically
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dolby\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4') # download if this doesn't downloaded automatically
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Dolby\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
print(lemmatizer.lemmatize("better", pos="a")) #a is for adjective
# Out:
# good

# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm

import spacy
sp = spacy.load('en_core_web_sm')
token = sp(u'better')
for word in token:
    print(word.text,  word.lemma_)
# Out:
# better well

# %% [markdown]
# * NLTK prints the output as “good,” whereas spaCy prints “well”—both are correct. Since lemmatization involves some amount of linguistic analysis of the word and its context, it is expected that it will take longer to run than stemming, and it’s also typically used only if absolutely necessary.
#  *  we typically lowercase the text before stemming. We also don’t remove tokens or lowercase the text before doing lemmatization because we have to know the part of speech of the word to get its lemma, and that requires all tokens in the sentence to be intact.

# %% [markdown]
# # Common pre-processing steps on a blob of text
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Other preprocessing steps

# %% [markdown]
# # Text Normalization
# * For example we might deal with another language other than english, GOAL : we have to detect news events from a collection of social media posts, some of the examples are
#  * Hi there, how are you doing?
#  * Hai there, HOW U DOING?
# * Then we might end up creating a dictionary to match these words like ,
#  * BASE_NORMS = {
#      "Hi":"Hai",
#      "you":"U",
#      ".":"...",
#  }
#
#  * ref : https://github.com/explosion/spaCy/blob/master/spacy/lang/norm_exceptions.py

# %% [markdown]
# # Language Detection
# * If we want to get reviews from users for a product , they might end up giving reviews in different laguages other than english.
# * So, first step to use NLP is getting that reviews converted to english , this can be done using Polyglot python library
# * ref : https://polyglot.readthedocs.io/en/latest/

# %%
# pip install polyglot

import polyglot
from polyglot.text import Text, Word
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [24], in <cell line: 3>()
#       1 # pip install polyglot
# ----> 3 import polyglot
#       4 from polyglot.text import Text, Word
#
# ModuleNotFoundError: No module named 'polyglot'

# %% [markdown]
# # CODE MIXING AND TRANSLITERATION

# %% [markdown]
# * Mixing - when a single sentence contains multiple language words.
#  * These days posts can be seen with multuiple language words
#    * Example : Bella Ciao, good to see you.
#    *               non-en  ,      en
# * Transliteration - Using english spelling for a non-en words
#  * Example :
#       * In telugu : Thinu - Eat
#       * In Hindi : Naam - Name
#       * In Japanese : Arigato - Thankyou
# * Both of these phenomena are common in multilingual communities and need to be handled during the pre-processing of text.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Advanced Processing

# %% [markdown]
# * to develop a system to identify person and organization names in our company’s collection of one million documents. The common pre-processing steps we discussed earlier may not be relevant in this context.
# * Identifying names requires us to be able to do POS tagging, as identifying proper nouns can be useful in identifying person and organization names

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp(u'Charles Spencer Chaplin was born on 16 April 1889 toHannah Chaplin (born Hannah Harriet Pedlingham Hill) and Charles Chaplin Sr')         
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.shape_, token.is_stop, token.pos)
# Out:
# Charles Charles PROPN Xxxxx False 96
# Spencer Spencer PROPN Xxxxx False 96
# Chaplin Chaplin PROPN Xxxxx False 96
# was be AUX xxx True 87
# born bear VERB xxxx False 100
# on on ADP xx True 85
# 16 16 NUM dd False 93
# April April PROPN Xxxxx False 96
# 1889 1889 NUM dddd False 93
# toHannah toHannah PROPN xxXxxxx False 96
# Chaplin Chaplin PROPN Xxxxx False 96
# ( ( PUNCT ( False 97
# born bear VERB xxxx False 100
# Hannah Hannah PROPN Xxxxx False 96
# Harriet Harriet PROPN Xxxxx False 96
# Pedlingham Pedlingham PROPN Xxxxx False 96
# Hill Hill PROPN Xxxx False 96
# ) ) PUNCT ) False 97
# and and CCONJ xxx True 89
# Charles Charles PROPN Xxxxx False 96
# Chaplin Chaplin PROPN Xxxxx False 96
# Sr Sr PROPN Xx False 96

# %% [markdown]
# * to identify if a given person and organization are related to each other in some way (e.g., Satya Nadella is related to Microsoft through the relation CEO).
# * This is known as the problem of relation extraction
# * think about what kind of pre-processing we need for this case. We need POS tagging, which we already know how to add to our pipeline.
# * We need a way of identifying person and organization names, which is a separate information extraction task known as named entity recognition (NER)
# * Apart from these two, we need a way to identify patterns indicating “relation” between two entities in a sentence. This requires us to have some form of syntactic representation of the sentence, such as parsing
# * Further, we also want a way to identify and link multiple mentions of an entity (e.g., Satya Nadella, Mr. Nadella, he, etc.). We accomplish this with the pre-processing step known as coreference resolution.

# %% [markdown]
# # Example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Finally, we have to consider the step-by-step procedures of pre-processing in each case, as summarized in Figure

# %% [markdown]
# ![pnlp_0211.png](attachment:pnlp_0211.png)

# %% [markdown]
# * POS tagging cannot be preceded by stop word removal, lowercasing, etc., as such processing affects POS tagger output by changing the grammatical structure of the sentence.
